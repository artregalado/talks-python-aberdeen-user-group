# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.arange(0,10)
y = np.random.randint(low=10,high=50,size=10)
plt.plot(x,y)

# %%
x = pd.Series(data=[1,2,3,4], index = ['one','two','three','four'])
y = pd.Series(data=[1,2,3,4,5], index = ['one','two','three','four','five'])
list_of_data = [x,y]
df = pd.concat(list_of_data, join='outer', axis=1)

# %%
df
# Out:
#          0  1
# one    1.0  1
# two    2.0  2
# three  3.0  3
# four   4.0  4
# five   NaN  5
